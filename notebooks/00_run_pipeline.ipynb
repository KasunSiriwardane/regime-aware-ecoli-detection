# %% [markdown]
# # River Risk pipeline runner
#
# Runs scripts in `src/` in order and writes datasets to `data/`.

# %%
from pathlib import Path
import subprocess, sys, textwrap

ROOT = Path.cwd()
# If you run this notebook from notebooks/, set ROOT to parent
if (ROOT / "src").exists() is False and (ROOT.parent / "src").exists():
    ROOT = ROOT.parent

print("Project root:", ROOT)
SCRIPTS = [
    "01_data_build_daily.py",
    "02_features_physics.py",
    "03_scores_storm_gate.py",
    "04_chronic_model_and_score.py",
    "05_tune_dry_threshold_and_base_regime.py",
    "06_micro_rescues.py",
    "07_review_gate_tiered_v6c.py",
    "08_metrics_and_exports.py",
    "09_sanity_checks.py",
]

def run_script(script_name: str) -> None:
    script_path = ROOT / "src" / script_name
    if not script_path.exists():
        raise FileNotFoundError(f"Missing script: {script_path}")
    print("="*80)
    print("RUNNING:", script_path.relative_to(ROOT))
    print("="*80)
    # Use the same Python environment as the notebook kernel
    subprocess.run([sys.executable, str(script_path)], check=True, cwd=str(ROOT))

for s in SCRIPTS:
    run_script(s)

print("\nDONE. Check the data/ folder for outputs.")
# Out:
# Project root: /Users/kasunsiriwardane/Library/CloudStorage/OneDrive-RogalandFylkeskommuneEES/KASUN-PROJECTS/river_risk_fixed
# ================================================================================
# RUNNING: src/01_data_build_daily.py
# ================================================================================
# --- PHASE 1: DATASET REBUILD (FINAL V6) ---
#
# [1/5] Building Continuous Daily Backbone...
#  > Backbone created. 9133 continuous days.
#
# [2/5] Fetching Daily Proxy Data (NWIS)...
#  Mapped Flow_cfs <- 00060_Mean
#  Mapped Rain_inches <- 00045_Sum
#  Mapped Temp_C <- 00010_Mean
#  Mapped Cond_uS <- 00095_Mean
#  Mapped Turbidity_FNU <- 63680_Mean
#  Mapped Turbidity_FNU_Max <- 63680_Maximum
#  > Flow Data Coverage: 100.0%
#
# [3/5] Fetching E. coli Samples...
#  > Raw Samples (Cleaned & Filtered): 2197
#  > Unique Daily Labels: 2172
#
# SUCCESS. Files saved to /Users/kasunsiriwardane/Library/CloudStorage/OneDrive-RogalandFylkeskommuneEES/KASUN-PROJECTS/river_risk_fixed/data
# ================================================================================
# RUNNING: src/02_features_physics.py
# ================================================================================
# --- PHASE 1.5: PROCESSING & CLEANING ---
#  > Creating Turbidity_Composite...
#  Composite Coverage: 85.3%
#
# --- PHASE 2: CAUSAL FEATURE ENGINEERING ---
#
# [MERGE FIX] Aggregating Samples to Daily Level...
#  > Assertion Passed: Row count preserved (9133).
#
# SUCCESS. Saved to /Users/kasunsiriwardane/Library/CloudStorage/OneDrive-RogalandFylkeskommuneEES/KASUN-PROJECTS/river_risk_fixed/data/02_features_modeled_v6.csv
# ================================================================================
# RUNNING: src/03_scores_storm_gate.py
# ================================================================================
# --- 03: STORM SCORE COMPLETE ---
# Saved: 03_scored_storm_v6.csv
# Saved: 03_storm_threshold_v6.json
# Best storm threshold: 0.755
# Storm share by split:
#   TRAIN: 47.6%
#   CALIB: 54.7%
#   VAULT: 57.0%
# ================================================================================
# RUNNING: src/04_chronic_model_and_score.py
# ================================================================================
# --- 04: CHRONIC MODEL COMPLETE ---
# Saved: 04_scored_storm_chronic_v6.csv
# Saved model: 04_chronic_model_xgb.json
# Non-storm TRAIN labels: 1073 | unsafe=66 | scale_pos_weight=15.26
# TRAIN non-storm AUC (raw): 0.999
# ================================================================================
# RUNNING: src/05_tune_dry_threshold_and_base_regime.py
# ================================================================================
# --- 05: DRY THRESHOLD + BASEFRESH REGIME COMPLETE ---
# Saved: 05_regime_basefresh_v6.csv
# Saved: 05_dry_threshold_v6.json
# best_storm_s=0.755 | best_t_dry=0.915
# Selection summary: {'t': 0.915, 'mincap': 0.9032258064516129, 'trainlate_capture': 1.0, 'calib_capture': 0.9032258064516129, 'calib_fpr_any': 0.4453125, 'calib_fpr_dry_nonstorm': 0.05333333333333334, 'calib_dryvol_nonstorm': 0.04669887278582931}
# ================================================================================
# RUNNING: src/06_micro_rescues.py
# ================================================================================
# --- 06: MICRO RESCUES COMPLETE ---
# Saved: 06_regime_micro_v6.csv
# Saved: 06_micro_summary_v6.json
# Micro counts: {'TRAIN': {'n_micro': 0, 'n_storm': 0, 'n_dry': 0}, 'CALIB': {'n_micro': 0, 'n_storm': 0, 'n_dry': 0}, 'VAULT': {'n_micro': 0, 'n_storm': 0, 'n_dry': 0}}
# ================================================================================
# RUNNING: src/07_review_gate_tiered_v6c.py
# ================================================================================
# --- 07: REVIEW GATE (v6c-style) COMPLETE ---
# Missed unsafe under HARD+MICRO (CALIB): 3
# Tight t_review (CALIB-only) = 0.061728
# Saved: 07_regime_final_v6c.csv
# Saved config: final_thresholds_tiered.json
#
# == HARD+MICRO ==
# TRAIN: Capture=99.7% | FPR=37.0% | Review=0.0%
# CALIB: Capture=90.3% | FPR=44.5% | Review=0.0%
# VAULT: Capture=88.9% | FPR=53.8% | Review=0.0%
#
# == FINAL (+REVIEW) ==
# TRAIN: Capture=99.7% | FPR=37.1% | Review=0.0%
# CALIB: Capture=100.0% | FPR=44.5% | Review=0.0%
# VAULT: Capture=88.9% | FPR=53.8% | Review=0.0%
# ================================================================================
# RUNNING: src/08_metrics_and_exports.py
# ================================================================================
# --- 08: METRICS + EXPORTS COMPLETE ---
# Saved: 08_metrics_summary.csv
# Saved: 08_confusion_by_split.csv
# Saved: 08_advisory_days.csv
#
# Key config:
#   best_storm_s=0.755
#   best_t_dry=0.915
#   t_review=0.0617283950617283
# ================================================================================
# RUNNING: src/09_sanity_checks.py
# ================================================================================
# --- 04: CHRONIC MODEL COMPLETE ---
# Saved: 04_scored_storm_chronic_v6.csv
# Saved model: 04_chronic_model_xgb.json
# Non-storm TRAIN labels: 1073 | unsafe=66 | scale_pos_weight=15.26
# TRAIN non-storm AUC (raw): 0.999
#
# DONE. Check the data/ folder for outputs.
